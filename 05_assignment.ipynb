# %%
import numpy
from matplotlib import pyplot
import math
# %matplotlib inline

# %%
x = numpy.linspace(-10,10,101)
y = numpy.linspace(-10,10,101)
X,Y = numpy.meshgrid(x,y)

# %%
gamma = 50.
Ngedian = 20
x_vortex = numpy.linspace(-10,10,Ngedian)
y_vortex = numpy.zeros(Ngedian)

# %%
u = numpy.zeros([101,101])
v = numpy.zeros_like(u)
psi = numpy.zeros_like(u)

# %%
for i in range(Ngedian):

    u_linshi = +gamma/(2*math.pi) *(Y-y_vortex[i])/((X-x_vortex[i])**2 + (Y - y_vortex[i])**2)
    v_linshi = -gamma/(2*math.pi) *(X-x_vortex[i])/((X-x_vortex[i])**2 + (Y - y_vortex[i])**2)
    psi_linshi = gamma/(4*math.pi) * numpy.log((X-x_vortex[i])**2 + (Y - y_vortex[i])**2)

    u = u+u_linshi
    v = v+v_linshi
    psi = psi +psi_linshi
# Out:
# C:\Users\55468\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\55468\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: invalid value encountered in true_divide
# C:\Users\55468\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: RuntimeWarning: divide by zero encountered in log

# %%
    psi_linshi = gamma/(4*math.pi)*numpy.log((X-x_vortex[i])**2 + (Y - y_vortex[i])**2)
# Out:
# C:\Users\55468\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: RuntimeWarning: divide by zero encountered in log
#   if __name__ == '__main__':

# %%
pyplot.figure(figsize=(10, 10))
pyplot.streamplot(X,Y,u,v,density=2, linewidth=1, arrowsize=1, arrowstyle='->')
pyplot.xlim(-10,10)
pyplot.ylim(-10,10)
pyplot.scatter(x_vortex, y_vortex)
# Out:
# C:\Users\55468\Anaconda3\lib\site-packages\numpy\ma\core.py:812: RuntimeWarning: invalid value encountered in greater_equal
#   return umath.absolute(a) * self.tolerance >= umath.absolute(b)

# %%
math.factorial(4)
# Out:
# 24
