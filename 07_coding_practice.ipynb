# %%
import numpy
from matplotlib import pyplot
# %matplotlib inline
import math

# %%
X=numpy.linspace(-5,5,200)
Y=numpy.linspace(-5,5,200)
X,Y=numpy.meshgrid(X,Y)

# %%
#practice of using class
class Source:
    """Contains information related to a source (or sink)."""
    def __init__(self, strength, x, y):
        """Initializes the singularity.
        
        Arguments
        ---------
        strength -- strength of the singularity.
        x, y -- coordinates of the singularity.
        """
        self.strength = strength
        self.x, self.y = x, y
        
    
    def velocity(self, X, Y):
        """Computes the velocity field generated by the singularity.
        
        Arguments
        ---------
        X, Y -- mesh grid.
        """
        self.u = self.strength/(2*math.pi)*(X-self.x)/((X-self.x)**2+(Y-self.y)**2)
        self.v = self.strength/(2*math.pi)*(Y-self.y)/((X-self.x)**2+(Y-self.y)**2)
        return self.u, self.v
    
    def stream_function(self, X, Y):
        """Computes the stream-function generated by the singularity.
        
        Arguments
        ---------
        X, Y -- mesh grid.
        """
        self.psi = self.strength/(2*math.pi)*numpy.arctan2((Y-self.y), (X-self.x))

# %%
aa=Source(1,1,1)

# %%
uu,vv = aa.velocity(X,Y)

# %%
aa.u==uu
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]], dtype=bool)

# %%
aa.psi
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-23-4fb4b9591426> in <module>()
# ----> 1 aa.psi
#
# AttributeError: 'Source' object has no attribute 'psi'

# %%
aa.stream_function(X,Y)

# %%
aa.psi
# Out:
# array([[-0.375     , -0.37433072, -0.37365582, ..., -0.15827641,
#         -0.15734287, -0.15641648],
#        [-0.37566928, -0.375     , -0.37432505, ..., -0.15766375,
#         -0.15672709, -0.15579768],
#        [-0.37634418, -0.37567495, -0.375     , ..., -0.15704381,
#         -0.15610404, -0.15517165],
#        ...,
#        [ 0.40827641,  0.40766375,  0.40704381, ...,  0.125     ,
#          0.1239811 ,  0.12297524],
#        [ 0.40734287,  0.40672709,  0.40610404, ...,  0.1260189 ,
#          0.125     ,  0.12399398],
#        [ 0.40641648,  0.40579768,  0.40517165, ...,  0.12702476,
#          0.12600602,  0.125     ]])
